# %% [markdown]
# Nour Sameh El Barbary
#
# <font size='5'> **Data Description :** </font>
# - **Item_Identifier :** A unique identifier for the item.
# - **Item Weight :** The weight of the item in grams.
# - **Item Fat Content :** The fat content of the item.
# - **Item Visibility :** The visibility of the item in the store.
# - **Item Type :** The type of item (e.g., dairy, soft drinks, meat, fruits and vegetables, household, baking goods, snack foods, frozen foods).
# - **Item MRP :** The maximum retail price of the item.
# - **Outlet Identifier :** A unique identifier for the outlet where the item was sold.
# - **Outlet Establishment Year :** The year the outlet was established.
# - **Outlet Size :** The size of the outlet (e.g., small, medium, large).
# - **Outlet Location Type :** The type of location the outlet is in (e.g., Tier 1, Tier 2, Tier 3).
# - **Outlet Type :** The type of outlet (e.g., Supermarket Type1, Supermarket Type2, Supermarket Type3, Grocery Store).
# - **Item Outlet Sales :** The sales of the item at the outlet.

# %% [markdown]
# **Importing libraries.**

# %%
import pandas as pd
import numpy as np


#ploting libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
df = pd.read_csv('/content/data.csv')

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.head(15)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 3            FDX07       19.200          Regular         0.000000
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 7            FDP10          NaN          Low Fat         0.127470
# 8            FDH17       16.200          Regular         0.016687
# 9            FDU28       19.200          Regular         0.094450
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
#rows and columns
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# ##  7 object columns we need to delete or encode.

# %% [markdown]
# ### missing values

# %%
missing_values = df.isnull()
missing_count = missing_values.sum()
missing_count
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# ## it is Item_Weight 1463 numerical so we need to plot it to see the outliers

# %%
sns.boxplot(data=df['Item_Weight'],orient="v")
# Out:
# <Axes: >

# %%
item_weight = df["Item_Weight"].value_counts()
item_weight
# Out:
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 7.275      2
# 7.685      1
# 9.420      1
# 6.520      1
# 5.400      1
# Name: Item_Weight, Length: 415, dtype: int64

# %%
missing_values = df.isnull()
missing_count = missing_values.sum()
missing_count
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# **No outliers so will fill with the mean**

# %%
#1st problem null values
mean_item_weight = df['Item_Weight'].mean()
print("Mean of 'Item_Weight':", mean_item_weight)
# Out:
# Mean of 'Item_Weight': 12.857645184135976

# %%
df['Item_Weight'] =df['Item_Weight'].fillna(df['Item_Weight'].dropna().mean())

# %%
missing_val= df['Item_Weight'].isnull().sum()

missing_val
# Out:
# 0

# %% [markdown]
# ## Outlet_Size 6113 non-null   object as it is catigorical feature so will fill the missing by the mode value(most repeated value which is the medium)

# %%
outlet_size_cnt = df['Outlet_Size'].value_counts()
outlet_size_cnt
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
print("data mode:", df['Outlet_Size'].mode().values[0])
df['Outlet_Size'].fillna(df['Outlet_Size'].mode().values[0], inplace=True)
# Out:
# data mode: Medium

# %%
outlet_size_cnt = df['Outlet_Size'].value_counts()
outlet_size_cnt
# Out:
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.info()
#no null val 1st problem solved
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
#2nd problem let the catigorical numeric

#list of all the numeric columns
num = df.select_dtypes('number').columns.to_list()
#list of all the categoric columns
cat = df.select_dtypes('object').columns.to_list()

# %%
num
# Out:
# ['Item_Weight',
#  'Item_Visibility',
#  'Item_MRP',
#  'Outlet_Establishment_Year',
#  'Item_Outlet_Sales']

# %%
cat
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
[df[category].value_counts() for category in cat[0:]]
# Out:
# [FDW13    10
#  FDG33    10
#  NCY18     9
#  FDD38     9
#  DRE49     9
#           ..
#  FDY43     1
#  FDQ60     1
#  FDO33     1
#  DRF48     1
#  FDC23     1
#  Name: Item_Identifier, Length: 1559, dtype: int64,
#  Low Fat    5089
#  Regular    2889
#  LF          316
#  reg         117
#  low fat     112
#  Name: Item_Fat_Content, dtype: int64,
#  Fruits and Vegetables    1232
#  Snack Foods              1200
#  Household                 910
#  Frozen Foods              856
#  Dairy                     682
#  Canned                    649
#  Baking Goods              648
#  Health and Hygiene        520
#  Soft Drinks               445
#  Meat                      425
#  Breads                    251
#  Hard Drinks               214
#  Others                    169
#  Starchy Foods             148
#  Breakfast                 110
#  Seafood                    64
#  Name: Item_Type, dtype: int64,
#  OUT027    935
#  OUT013    932
#  OUT049    930
#  OUT046    930
# ...

# %% [markdown]
# # deduced duplicates in
#
# *   Item_Fat_Content
#
# *   Outlet_Identifier
#
#
# 1.   OUT035 and OUT046  and OUT049
#
# 2.   OUT018 and OUT019

# %% [markdown]
# ##there are repeated in fat content with diff nmes lf and low fat , reg ,regular

# %%
#obviously Low fat is lf and also low fat
# and reg is regular so will concatinate

# %%
df['Item_Fat_Content'].replace(['LF','reg','low fat'], ['Low Fat','Regular','Low Fat'], inplace = True)

# %%
df.Item_Fat_Content.value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# ## also there are duplicates in outlet identefiers

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#Outlet_Establishment_Year will convet it to age so subtract from corrent year
df['age']= df['Outlet_Establishment_Year'].apply(lambda year: 2023 - year)

df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#dropping Establishment_Year
df.drop(columns ='Outlet_Establishment_Year' ,inplace = True)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 0                  Dairy  249.8092            OUT049      Medium
# 1            Soft Drinks   48.2692            OUT018      Medium
# 2                   Meat  141.6180            OUT049      Medium
# 3  Fruits and Vegetables  182.0950            OUT010      Medium
# 4              Household   53.8614            OUT013        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  age
# 0               Tier 1  Supermarket Type1          3735.1380   24
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Identifier       8523 non-null   object
#  1   Item_Weight           8523 non-null   float64
#  2   Item_Fat_Content      8523 non-null   object
#  3   Item_Visibility       8523 non-null   float64
#  4   Item_Type             8523 non-null   object
#  5   Item_MRP              8523 non-null   float64
#  6   Outlet_Identifier     8523 non-null   object
#  7   Outlet_Size           8523 non-null   object
#  8   Outlet_Location_Type  8523 non-null   object
#  9   Outlet_Type           8523 non-null   object
#  10  Item_Outlet_Sales     8523 non-null   float64
#  11  age                   8523 non-null   int64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# ## some plotting

# %%
sns.heatmap(df.corr() , annot=True )
# Out:
# <ipython-input-428-38ae9096cb3b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr() , annot=True )
# <Axes: >

# %%
# The item outlet sale correlates with Item MRP : The maximum retail price of the item.

# %%
df.hist(figsize=(10,10 ))
# Out:
# array([[<Axes: title={'center': 'Item_Weight'}>,
#         <Axes: title={'center': 'Item_Visibility'}>],
#        [<Axes: title={'center': 'Item_MRP'}>,
#         <Axes: title={'center': 'Item_Outlet_Sales'}>],
#        [<Axes: title={'center': 'age'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ### conclusion about histogram wich plot ** numerical values only
# 1.  item weight peak is 12.5 as we filled the missing val with mode
# 2.   item visability 0 not sold
# 3.   max age is 35

# %%
sns.countplot(x = 'Outlet_Location_Type', data = df)
# Out:
# <Axes: xlabel='Outlet_Location_Type', ylabel='count'>

# %%
sns.countplot(x = 'Outlet_Type', data = df)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# %%
sns.countplot(x='Outlet_Identifier' , data =df )

plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# %%
sns.countplot(x='Item_Fat_Content', data=df)

plt.show()

# %% [markdown]
# ## We noticed that the maximum column is fruits and veg

# %%
sns.countplot(x='Item_Type', data = df)

#to make column names visible
ax = sns.countplot(x='Item_Type', data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=60)

plt.show()

# %% [markdown]
# ## We concluded from the above plots that
# ### most loc tier 3 , supemarket1 , lowfat , fruits and veg

# %%
#list of all the numeric columns
num = df.select_dtypes('number').columns.to_list()

for col in num:
    sns.scatterplot(x=col, y="Item_Outlet_Sales", data=df, hue="Item_Outlet_Sales", palette="cool")

    plt.show()

# %%
sns.barplot(x = 'Outlet_Size' , y = 'Item_Outlet_Sales' , data = df)
# Out:
# <Axes: xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %%
sns.barplot(x = 'Outlet_Location_Type' , y = 'Item_Outlet_Sales' , data = df)
# Out:
# <Axes: xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 0                     Dairy  249.8092            OUT049      Medium
# ...

# %%
categorical_columns = ['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

for column in categorical_columns:
    unique_categories_count = df[column].nunique()
    print(f'Unique categories in {column}: {unique_categories_count}')
# Out:
# Unique categories in Item_Identifier: 1559
# Unique categories in Item_Fat_Content: 2
# Unique categories in Item_Type: 16
# Unique categories in Outlet_Identifier: 10
# Unique categories in Outlet_Size: 3
# Unique categories in Outlet_Location_Type: 3
# Unique categories in Outlet_Type: 4

# %%
num_unique_values = df['Item_Identifier'].nunique()
num_unique_values
# Out:
# 1559

# %%
category_counts = df['Item_Identifier'].value_counts()
category_counts
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
rows_with_FDG33 = df[df['Item_Identifier'] == 'FDG33']
print(rows_with_FDG33)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 231            FDG33    12.857645          Regular         0.139561   Seafood
# 1202           FDG33     5.365000          Regular         0.140525   Seafood
# 1575           FDG33    12.857645          Regular         0.245543   Seafood
# 2728           FDG33     5.365000          Regular         0.234733   Seafood
# 4747           FDG33     5.365000          Regular         0.140458   Seafood
# 5164           FDG33     5.365000          Regular         0.140240   Seafood
# 6112           FDG33     5.365000          Regular         0.141034   Seafood
# 7011           FDG33     5.365000          Regular         0.140812   Seafood
# 7098           FDG33     5.365000          Regular         0.140124   Seafood
# 7726           FDG33     5.365000          Regular         0.140214   Seafood
#
#       Item_MRP Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# ...

# %%
rows_with_FDW13 = df[df['Item_Identifier'] == 'FDW13']
print(rows_with_FDW13)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 256            FDW13     8.500000          Low Fat         0.098438    Canned
# 1141           FDW13     8.500000          Low Fat         0.097866    Canned
# 2190           FDW13     8.500000          Low Fat         0.098283    Canned
# 3928           FDW13    12.857645          Low Fat         0.097411    Canned
# 3978           FDW13     8.500000          Low Fat         0.098037    Canned
# 6499           FDW13     8.500000          Low Fat         0.098083    Canned
# 6587           FDW13     8.500000          Low Fat         0.163839    Canned
# 7029           FDW13     8.500000          Low Fat         0.097803    Canned
# 8025           FDW13    12.857645          Low Fat         0.171384    Canned
# 8032           FDW13     8.500000          Low Fat         0.097885    Canned
#
#       Item_MRP Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# ...

# %%
#from the above deduced that Item_Identifier is groupped column in a certain type of code  for ( Item_Fat_Content ,Item_Type :FD, DR or NC :Food, Drinks and Non-Consumables )
# so we will create new column  Item_Type_Combined

# %%
df['Item_Type_Combined'] = df['Item_Identifier'].apply(lambda x: x[0:2])
#Rename them to more intuitive categories:
df['Item_Type_Combined'] = df['Item_Type_Combined'].map({'FD':'Food',
                                                             'NC':'Non-Consumable',
                                                             'DR':'Drinks'})
df['Item_Type_Combined'].value_counts()
# Out:
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: Item_Type_Combined, dtype: int64

# %%
#df.drop( columns=['Item_Identifier'], inplace = True )

# %%
df.head(15)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15     9.300000          Low Fat         0.016047
# 1            DRC01     5.920000          Regular         0.019278
# 2            FDN15    17.500000          Low Fat         0.016760
# 3            FDX07    19.200000          Regular         0.000000
# 4            NCD19     8.930000          Low Fat         0.000000
# 5            FDP36    10.395000          Regular         0.000000
# 6            FDO10    13.650000          Regular         0.012741
# 7            FDP10    12.857645          Low Fat         0.127470
# 8            FDH17    16.200000          Regular         0.016687
# 9            FDU28    19.200000          Regular         0.094450
# 10           FDY07    11.800000          Low Fat         0.000000
# 11           FDA03    18.500000          Regular         0.045464
# 12           FDX32    15.100000          Regular         0.100014
# ...

# %%
#uique categories of Outlet_Identifier
num_unique_categories = df['Outlet_Identifier'].nunique()
num_unique_categories
# Out:
# 10

# %%
#checking for null values by Outlet_Identifier
df[df['Outlet_Size'].isnull()]['Outlet_Identifier'].unique()
# Out:
# array([], dtype=object)

# %%
[df[category].value_counts() for category in cat[3:4]]
# Out:
# [OUT027    935
#  OUT013    932
#  OUT049    930
#  OUT046    930
#  OUT035    930
#  OUT045    929
#  OUT018    928
#  OUT017    926
#  OUT010    555
#  OUT019    528
#  Name: Outlet_Identifier, dtype: int64]

# %%
#seeing if thir is a pattern for the most repeated cat in Outlet_Identifier  to replace the null in this column
rows_with_OUT027 = df[df['Outlet_Identifier'] == 'OUT027']
print(rows_with_OUT027)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10    12.857645          Low Fat         0.127470
# 18             DRI11    12.857645          Low Fat         0.034238
# 21             FDW12    12.857645          Regular         0.035400
# 36             FDV20    12.857645          Regular         0.059512
# 38             FDX10    12.857645          Regular         0.123111
# ...              ...          ...              ...              ...
# 8472           NCS41    12.857645          Low Fat         0.053185
# 8485           DRK37    12.857645          Low Fat         0.043792
# 8487           DRG13    12.857645          Low Fat         0.037006
# 8488           NCN14    12.857645          Low Fat         0.091473
# 8504           NCN18    12.857645          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 7               Snack Foods  107.7622            OUT027      Medium
# ...

# %%
rows_with_OUT013 = df[df['Outlet_Identifier'] == 'OUT013']
print(rows_with_OUT013)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 14             FDF32       16.350          Low Fat         0.068024
# 20             FDN22       18.850          Regular         0.138190
# 27             DRJ59       11.650          Low Fat         0.019356
# ...              ...          ...              ...              ...
# 8462           FDQ31        5.785          Regular         0.053802
# 8466           FDJ32       10.695          Low Fat         0.057744
# 8484           DRJ49        6.865          Low Fat         0.000000
# 8512           FDR26       20.700          Low Fat         0.042801
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 4                 Household   53.8614            OUT013        High
# ...

# %%
# Outlet_Identifier is a concatination of (Outlet_Type , Outlet_Location_Type ,age)
# try each one of the columns to see which one is related the most

# %%
f

# %%
sns.catplot(data=df, x="Outlet_Location_Type", y="Outlet_Size")

# %%
sns.catplot(data=df, x="age", y="Outlet_Size")

# %%
df[df['Outlet_Location_Type']=='Tier 1']['Outlet_Size'].value_counts()
# Out:
# Small     1458
# Medium     930
# Name: Outlet_Size, dtype: int64

# %%
df[df['Outlet_Location_Type']=='Tier 2']['Outlet_Size'].value_counts()
# Out:
# Medium    1855
# Small      930
# Name: Outlet_Size, dtype: int64

# %%
df[df['Outlet_Location_Type']=='Tier 3']['Outlet_Size'].value_counts()
# Out:
# Medium    2418
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df['Outlet_Size'].isnull().sum()
# Out:
# 0

# %%
le = LabelEncoder()

# %%
df['Item_Identifier']=le.fit_transform(df['Item_Identifier'])
df['Outlet_Identifier']=le.fit_transform(df['Outlet_Identifier'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Identifier       8523 non-null   int64
#  1   Item_Weight           8523 non-null   float64
#  2   Item_Fat_Content      8523 non-null   object
#  3   Item_Visibility       8523 non-null   float64
#  4   Item_Type             8523 non-null   object
#  5   Item_MRP              8523 non-null   float64
#  6   Outlet_Identifier     8523 non-null   int64
#  7   Outlet_Size           8523 non-null   object
#  8   Outlet_Location_Type  8523 non-null   object
#  9   Outlet_Type           8523 non-null   object
#  10  Item_Outlet_Sales     8523 non-null   float64
#  11  age                   8523 non-null   int64
#  12  Item_Type_Combined    8523 non-null   object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 865.7+ KB

# %%
unique_value_counts = df.select_dtypes(include=['object']).nunique()

print("Number of unique values in each object column:")
print(unique_value_counts)
# Out:
# Number of unique values in each object column:
# Item_Fat_Content         2
# Item_Type               16
# Outlet_Size              3
# Outlet_Location_Type     3
# Outlet_Type              4
# Item_Type_Combined       3
# dtype: int64

# %%
#label encode Item_Type and Outlet_Type

# %%
#lable encoding
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
Label = ['Item_Type','Outlet_Type','Item_Type_Combined','Outlet_Size','Item_Fat_Content']

for i in Label:
    df[i] = le.fit_transform(df[i])
    df[i] = le.fit_transform(df[i])

df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Size Outlet_Location_Type  Outlet_Type  \
# 0  249.8092                  9            1               Tier 1            1
# 1   48.2692                  3            1               Tier 3            2
# 2  141.6180                  9            1               Tier 1            1
# 3  182.0950                  0            1               Tier 3            0
# 4   53.8614                  1            0               Tier 3            1
#
# ...

# %%
unique_value_counts = df.select_dtypes(include=['object']).nunique()

print("Number of unique values in each object column:")
print(unique_value_counts)
# Out:
# Number of unique values in each object column:
# Outlet_Location_Type    3
# dtype: int64

# %%
#one-hot encoding for the least categorised columns

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
# Define the columns to one-hot encode

cols = ['Outlet_Location_Type']

# %%
# Apply one-hot encoder
OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)

# %%
# Fit the encoder and transform the columns
oh = OH_encoder.fit_transform(df[cols]).astype('uint8')

# Get the unique categories for each one-hot encoded column

categories = OH_encoder.categories_

# Combine categories with column names to create feature names
feature_names = [f"{col}_{cat}" for col, cats in zip(cols, categories) for cat in cats]


# Create a DataFrame from one-hot encoded data with feature names
oh = pd.DataFrame(oh, columns=feature_names)



# One-hot encoding removed index; put it back
oh.index = df.index


# Add one-hot encoded columns to the main DataFrame
df = pd.concat([df, oh], axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 0         0.016047
# 1                   8        5.920                 1         0.019278
# 2                 662       17.500                 0         0.016760
# 3                1121       19.200                 1         0.000000
# 4                1297        8.930                 0         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 0         0.056783
# 8519              897        8.380                 1         0.046982
# 8520             1357       10.600                 0         0.035186
# 8521              681        7.210                 1         0.145221
# 8522               50       14.800                 0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Size  \
# 0             4  249.8092                  9            1
# ...

# %%
#dropping columns after encoding

# %%
# Specify the columns you want to drop

columns_to_drop = ['Outlet_Size', 'Item_Fat_Content' , 'Outlet_Type', 'Item_Type_Combined','Outlet_Location_Type']

# %%
df.drop(columns=columns_to_drop, inplace=True)

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0                 156        9.300         0.016047          4  249.8092
# 1                   8        5.920         0.019278         14   48.2692
# 2                 662       17.500         0.016760         10  141.6180
# 3                1121       19.200         0.000000          6  182.0950
# 4                1297        8.930         0.000000          9   53.8614
# ...               ...          ...              ...        ...       ...
# 8518              370        6.865         0.056783         13  214.5218
# 8519              897        8.380         0.046982          0  108.1570
# 8520             1357       10.600         0.035186          8   85.1224
# 8521              681        7.210         0.145221         13  103.1332
# 8522               50       14.800         0.044878         14   75.4670
#
#       Outlet_Identifier  Item_Outlet_Sales  age  Outlet_Location_Type_Tier 1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Item_Identifier              8523 non-null   int64
#  1   Item_Weight                  8523 non-null   float64
#  2   Item_Visibility              8523 non-null   float64
#  3   Item_Type                    8523 non-null   int64
#  4   Item_MRP                     8523 non-null   float64
#  5   Outlet_Identifier            8523 non-null   int64
#  6   Item_Outlet_Sales            8523 non-null   float64
#  7   age                          8523 non-null   int64
#  8   Outlet_Location_Type_Tier 1  8523 non-null   uint8
#  9   Outlet_Location_Type_Tier 2  8523 non-null   uint8
#  10  Outlet_Location_Type_Tier 3  8523 non-null   uint8
# dtypes: float64(4), int64(4), uint8(3)
# memory usage: 557.8 KB

# %% [markdown]
# ## replacing outliers

# %%
def replace_outliers(col):
    Q1, Q3 = col.quantile(0.25), col.quantile(0.75)
    IQR = Q3 - Q1
    lower_range = Q1 - 1.5 * IQR
    upper_range = Q3 + 1.5 * IQR
    return lower_range, upper_range

# Define the columns you want to process
columns = ['Item_Weight', 'Item_Visibility', 'Item_Type', 'Item_MRP', 'Item_Outlet_Sales', 'age']

# Loop through columns and replace outliers
for col in columns:
    if df[col].dtype != 'object':
        lower_limit, upper_limit = replace_outliers(df[col])
        df[col] = df[col].clip(lower_limit, upper_limit)
        print(f"Replaced outliers in {col}. Lower limit: {lower_limit}, Upper limit: {upper_limit}")
# Out:
# Replaced outliers in Item_Weight. Lower limit: -0.7249999999999996, Upper limit: 26.035
# Replaced outliers in Item_Visibility. Lower limit: -0.07440424500000001, Upper limit: 0.195979015
# Replaced outliers in Item_Type. Lower limit: -5.0, Upper limit: 19.0
# Replaced outliers in Item_MRP. Lower limit: -43.8993, Upper limit: 323.3695
# Replaced outliers in Item_Outlet_Sales. Lower limit: -2566.3261, Upper limit: 6501.8699
# Replaced outliers in age. Lower limit: -6.5, Upper limit: 61.5

# %%
# Handle outliers without removing rows
for col in columns:
    # Calculate interquartile range (IQR)
    q25, q75 = df[col].quantile(0.25), df[col].quantile(0.75)
    iqr = q75 - q25

    # Define lower and upper limits for outliers
    lower_limit = q25 - 1.5 * iqr
    upper_limit = q75 + 1.5 * iqr

    # Clip the values to the lower and upper limits
    df[col] = df[col].clip(lower_limit, upper_limit)

    # Print the number of outliers removed
    num_outliers = len(df[(df[col] < lower_limit) | (df[col] > upper_limit)])
    print(f'Replaced outliers in {col}. Number of outliers removed: {num_outliers}')
# Out:
# Replaced outliers in Item_Weight. Number of outliers removed: 0
# Replaced outliers in Item_Visibility. Number of outliers removed: 0
# Replaced outliers in Item_Type. Number of outliers removed: 0
# Replaced outliers in Item_MRP. Number of outliers removed: 0
# Replaced outliers in Item_Outlet_Sales. Number of outliers removed: 0
# Replaced outliers in age. Number of outliers removed: 0

# %%
# Create box plots to visualize outliers after handling
for col in columns:
    if df[col].dtype != 'object':
        plt.figure(figsize=(8, 4))
        sns.boxplot(x=df[col])
        plt.title(f'Box Plot of {col} (Outliers Handled)')
        plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Item_Identifier              8523 non-null   int64
#  1   Item_Weight                  8523 non-null   float64
#  2   Item_Visibility              8523 non-null   float64
#  3   Item_Type                    8523 non-null   int64
#  4   Item_MRP                     8523 non-null   float64
#  5   Outlet_Identifier            8523 non-null   int64
#  6   Item_Outlet_Sales            8523 non-null   float64
#  7   age                          8523 non-null   int64
#  8   Outlet_Location_Type_Tier 1  8523 non-null   uint8
#  9   Outlet_Location_Type_Tier 2  8523 non-null   uint8
#  10  Outlet_Location_Type_Tier 3  8523 non-null   uint8
# dtypes: float64(4), int64(4), uint8(3)
# memory usage: 557.8 KB

# %% [markdown]
# ## splitting data

# %%
from sklearn.model_selection import train_test_split

# %%
#split data
# x independent , y dependent

X=df.drop(columns=['Item_Type','Item_Outlet_Sales','age','Outlet_Identifier','Item_Weight'])

y = df ['Item_Type']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2 )

# %%
# KNN model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
K =  KNeighborsClassifier(n_neighbors=3)
K.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
#predections
predictions=K.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, predictions)
print('accuracy: ',accuracy)
# Out:
# accuracy:  0.9472140762463344
